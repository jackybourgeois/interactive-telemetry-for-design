# %%
import importlib
from src import sequencing
importlib.reload(sequencing);
# Out:
# Traceback (most recent call last):
#
#   File ~/interactive-telemetry-for-design/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 2
#     from src import sequencing
#
#   File ~/interactive-telemetry-for-design/src/sequencing.py:86
#     def get_sequences_labels_only_labeled()
#                                            ^
# SyntaxError: expected ':'
